# %%
import pandas as pd

# %%
#load the contents of a file into a pandas Dataframe

fb = pd.read_csv('data/facebook.csv')
ms = pd.read_csv('data/microsoft.csv')

# %%
ms['MA10']= ms['Close'].rolling(10).mean() #fast signal
ms['MA50']= ms['Close'].rolling(50).mean() #slow signal

# %% [markdown]
# #### Plot the stock price with two moving averages

# %%
print(ms.columns)
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', 'MA10'], dtype='object')

# %%
ms['Close'].plot(legend=True)
ms['MA10'].plot(legend=True) 
# ms['MA50'].plot(legend=True)
# Out:
# <Axes: >

# %%
#long or not
# ms['Shares'] = [ 1 if ms.loc[ei, 'MA10']>ms.loc[ei, 'MA50'] else 0 for ei in ms.index]

# %% [markdown]
# #### Daily Profit

# %%
ms['Profit'] = [ms.loc[ei, 'Close'] - ms.loc[ei, 'Close']
                if ms.loc[ei, 'Shares'] == 1
                else 0 for ei in ms.index]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Shares'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 ms['Profit'] = [ms.loc[ei, 'Close'] - ms.loc[ei, 'Close']
#       2                 if ms.loc[ei, 'Shares'] == 1
#       3                 else 0 for ei in ms.index]
#
# Cell In[11], line 2, in <listcomp>(.0)
#       1 ms['Profit'] = [ms.loc[ei, 'Close'] - ms.loc[ei, 'Close']
# ----> 2                 if ms.loc[ei, 'Shares'] == 1
#       3                 else 0 for ei in ms.index]
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexing.py:1183, in _LocationIndexer.__getitem__(self, key)
#    1181     key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#    1182     if self._is_scalar_access(key):
# -> 1183         return self.obj._get_value(*key, takeable=self._takeable)
#    1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:4202, in DataFrame._get_value(self, index, col, takeable)
#    4199     series = self._ixs(col, axis=1)
#    4200     return series._values[index]
# -> 4202 series = self._get_item_cache(col)
#    4203 engine = self.index._engine
#    4205 if not isinstance(self.index, MultiIndex):
#    4206     # CategoricalIndex: Trying to use the engine fastpath may give incorrect
#    4207     #  results if our categories are integers that dont match our codes
#    4208     # IntervalIndex: IntervalTree has no get_loc
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:4626, in DataFrame._get_item_cache(self, item)
#    4621 res = cache.get(item)
#    4622 if res is None:
#    4623     # All places that call _get_item_cache have unique columns,
#    4624     #  pending resolution of GH#33047
# -> 4626     loc = self.columns.get_loc(item)
#    4627     res = self._ixs(loc, axis=1)
#    4629     cache[item] = res
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Shares'
